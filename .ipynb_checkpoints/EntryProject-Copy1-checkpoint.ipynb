# %%
import pandas as pd

dataset = pd.read_csv('datasets/ecommerceDataset.csv', header=None)

# %%
categories = dataset[0].unique()
categories
# Out:
# array(['Household', 'Books', 'Clothing & Accessories', 'Electronics'],
#       dtype=object)

# %%
dataset.groupby(0).describe()
# Out:
#                             1
#                         count unique
# 0
# Books                   11820   6256  \
# Clothing & Accessories   8670   5674
# Electronics             10621   5308
# Household               19313  10564
#
#
#                                                                       top freq
# 0
# Books                   Think & Grow Rich About the Author NAPOLEON HI...   30
# Clothing & Accessories  Diverse Men's Formal Shirt Diverse is a wester...   23
# Electronics             HP 680 Original Ink Advantage Cartridge (Black...   26
# Household               Nilkamal Series-24 Chest of Drawers (Cream Tra...   13

# %%
dataset_books = dataset[dataset[0] == 'Books']

dataset_clo = dataset[dataset[0] == 'Clothing & Accessories']

dataset_elec = dataset[dataset[0] == 'Electronics']

dataset_house = dataset[dataset[0] == 'Household']

# %%
dataset_elec = dataset_elec.head(dataset_clo.shape[0])
dataset_elec.shape

dataset_books = dataset_books.head(dataset_clo.shape[0])
dataset_books.shape

dataset_house = dataset_house.head(dataset_clo.shape[0])
dataset_house.shape
# Out:
# (8671, 2)

# %%
datasets_arr = [dataset_books, dataset_house, dataset_clo, dataset_elec]
datasets_merged = pd.concat(datasets_arr)
datasets_merged
# Out:
#                  0                                                  1
# 19313        Books  Inner Engineering: A Yogi's Guide to Joy About...
# 19314        Books       Muslims and Missionaries in Pre-Mutiny India
# 19315        Books  The PCOD - Thyroid Book - Compiled From Women ...
# 19316        Books  The Monk Who Sold His Ferrari Review Everyone ...
# 19317        Books  The Secret of Secrets: The Secrets of the Gold...
# ...            ...                                                ...
# 48470  Electronics  LG GH24NSD1 Internal SATA DVD Writer The M-DIS...
# 48471  Electronics  LG GP65NB60 External DVD Writer (Black) LG GP6...
# 48472  Electronics  PIONEER DVD PLAYER DV-3052V Pioneer DV-3052 Mu...
# 48473  Electronics  LG DP546 DVD Player (Black) DivX-This is a for...
# 48474  Electronics  PODOFO 10.9cm Foldable TFT Color LCD Car Monit...
#
# [34684 rows x 2 columns]

# %%
labels = datasets_merged[0]
texts = datasets_merged[1]
labels.head(10)
cols = datasets_merged.select_dtypes(include=['object'])
for col in cols.columns.values:
    datasets_merged[col] = datasets_merged[col].fillna('')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils
import numpy as np


# encode class values as integers
encoder = LabelEncoder()
encoder.fit(labels)
encoded_Y = encoder.transform(labels)
# convert integers to dummy variables (i.e. one hot encoded)
y_cat = np_utils.to_categorical(encoded_Y)
y_cat = y_cat.astype(float)

x_train, x_test, y_train, y_test = train_test_split(texts, y_cat, test_size=0.2)
x_train.dtype
# Out:
# dtype('O')

# %%
# df_text = datasets_merged[1].values
# df_label = datasets_merged[0].values

# x_train = df_text[:4000]
# x_test = df_text[4000:4100]

# y_train = df_label[:4000]
# y_test = df_label[4000:4100]

# %%
from sklearn.feature_extraction.text import CountVectorizer
sentences = ['Rashmi likes ice cream', 'Rashmi hates chocolate.']
type(sentences)
# Out:
# list

# %%
vectorizer = CountVectorizer(min_df=0, lowercase=False)
#  'Nikon D3400 24.2MP Digital SLR (Black), AF-P DX NIKKOR 18-55mm f/3.5-5.6G VR Lens, AF-P DX NIKKOR 70-300mm f/4.5-6.3G ED VR Lens, 8GB Card, Camera Bag Nikon India is pleased to announce and sales start of most looked forward new model D-SLR D3400, it is the first entry-level D-SLR enabled with SnapBridge connectivity via a built-in Bluetooth low energy technology that automatically transfers all photos\xa0taken with the camera to a smart device\xa0with simple, one-time set-up. This eliminates the need to manually reconnect the camera to a smart device for each image transfer and connection is maintained even when the camera is turned off. Now sharing of images taken from the D-SLR onto social media has never been easier. For the always-connected user the D3400 is an excellent introduction to D-SLR photography. It combines best of both worlds and will allow users to innovate with excellent image quality and also enjoy connectivity on the go with their smart devices to upload and share images.\xa0With SnapBridge connectivity via a built-in Bluetooth low energy technology, D3400 will allow users to transfer all pictures clicked with the camera to a smart device automatically. Users will no more need to manually pair the devices each time to select and transfer images, thus making on-the-go share possible even with a D-SLR. On the picture quality front, D3400 integrates a DX-format CMOS sensor which will lead to sharper images in spite of low light conditions.',
#  'Amazon Brand - Solimo Votive Glass Candles, Pack of 12 (Unscented) Size:Pack of 12   Every Solimo product is carefully built to deliver exceptional quality. Right from the materials used, to detailed quality checks, to thoughtful improvements, quality is at the core of everything we do.',
#  'Grade 4 Writing (Kumon Writing Workbooks) NA',
#  "2pcs Moneekar Jewels High Quality Her King His Queen Titanium Stainless Steel Black Wedding Band Set Anniversary Engagement Promise Friendship valentines day Rings for Couples (PLEASE SELECT MEN & WOMEN PAIR SIZE FROM STYLE OPTION AS PER YOUR REQUIREMENT) PLEASE SELECT PAIR SIZE FOR MEN & WOMEN FROM STYLE OPTION AS PER YOUR REQUIREMENT. IT COMES IN PAIR BUT NEED TO SELECT PAIR OF MEN & WOMEN FROM STYLE OPTION. SALE PRICE IS FOR 2 RINGS, IT COMES IN PAIR WITH JEWELLERY RING BOX.RING MEASURING IS GIVEN ON IMAGES FOR YOU REFERENCE. These Black beautiful and stylish rings are both comfort fit. If you are looking for a ring that is scratch proof and forever keep its shine, then our titanium rings are for you. They are absolutely beautiful in person and what you see is what you get. The design is lovely and smooth. It feels good to the touch. Perfect gift idea for couples. It's like you have each other's heart beat with you always. The instead also is just like the picture with Tungsten Love stamped on it. The shipping is much faster than expected.",
#  'Mi 3C Router (White, Not a Modem) 4 high-performance antennas: Supports up to 300Mbps with 802.11n. Forget Wi-Fi dead zones and dropped connections. With its four high-performance antennas, Mi Router 3C boasts of increased operating range and stronger signal. Everyone on the network will enjoy low-latency online gaming, smooth video streaming, and seamless web browsing. Securely update using dual ROM partition system-Upgrading firmware is safer than you think. Updating firmware has never been safer. Using its dual partition system configured on high-speed 16MB flash storage, Mi Router 3C receives the latest firmware updates on schedule - even if unexpected power outage occurs. Experience blazing fast wireless speeds-Third party applications and connected devices consume valuable router RAM. This is why Mi Router 3C comes with 64MB of RAM - eight times more than typical routers. Mi Router 3C ensures smooth online gaming and browsing experiences. Mi Wi-Fi app puts you in command of your network. Anywhere, anytime. View and manage settings remotely. Whether is blacklisting unwanted internet activity or setting time limits on child. Internet usage, you can do it all right from your phone.',
#  "Yjack Creation Girl's Banglory Silk Semi-Stitched Lehenga Choli (Kids_8-12 Years Age_Free Size)",
# ...
#  'Joyo Multi-Utility Compact Foldable Table,(Mushroom & Silver Color) 1 pc Well Designed for Kids writing purpose & for laptop. Multi-purpose in Use - Can be Used as a Laptop Desk, Study Desk, Reading Desk, Working Desk, Writing Desk, Breakfast Table, etc. Can store daily writing books in desk compartment, can store pens, pencils, eraser, sharpeners, crayons, colors, scissor, glue and all your daily stationery. No Assembly Required as a 3 year old kid can also open the foldable table easily. Well planned and attractive design with storage compartments. Light Weight so that you can carry it in your car for a vacation where your kid can enjoy drawing and painting of a landscape below the tree or on a beach. Can Be Put On Your Lap and Work On the Sofa, Bed, Lawns, Carpet Etc. . Can be wiped with a soft, sparsely wet cloth. Can put any type of stationary item like books, calculator, pens Etc.',
#  'Okayji Self Adhesive Felt Material Pads for Furniture Floor Scratch Protection Guards, 33 Pieces (Mix Shape and Size) This product is from the house of spider juice. This anti-skid felt material foam protection pads are great for protecting floor and household surface from scratch caused by furniture, and also use to fill uneven legs of furniture and appliances. It is designed with anti-skid felt material foam material and to be self-adhesive, just peel the protector pad from the backing sheet and position the pad on to the surface where it to be. 1. Easy to install. Make sure to clean and dry the chair feet, then stick the self-adhesive felt pad. we recommend to install it at night then wait 12 hours before start to use the chair.2. These EVA felt pad also apply to recover the uneven or damaged of the foot.3. Protect the floor from scratches.4. Prevent noise when dragging furniture create a quiet environment.5. Anti-skid. Self-adhesive on the back side strongly stick to furniture feet prevent slippage between the floor and furniture.',
#  'Sigma 150-600 mm f/5-6.3 DG OS HSM Contemporary Lens for Canon Cameras Style name:Canon EF Cameras   The Sigma 150-600mm 5-6.3 DG HSM OS Contemporary was created around the concept of maximum portability meets utmost image quality in a variable aperture hyper-telephoto zoom lens. Light weight and compact, this s zoom can handle any long-reach photographic situation one may encounter. This 150-600mm Contemporary boasts updated Sigma technology such as a quiet and optimized Hyper Sonic Motor (HSM) and a new Optical Stabilizer (OS) with an accelerometer for improved panning photography both vertically and horizontally, essential for birding, wildlife and motor photography. The Sigma 150-600 Contemporary also touts a new zoom lock switch that can be locked at any focal length and a new manual override (MO) switch is incorporated for improved focusing control. Working with the Sigma USB dock, this lens allows for maximum customization such as firmware updates and adjustments to the focus limiter, AF speed and OS view.',
#  'Sony NWZ-B183F Digital Music Player (Blue) Colour:Blue   Good Sound Quality',
#  "Borosil Classic Tea Set, 7-Pieces Product Description You demand the best of yourself, so it's only right you enjoy the best from us. Famous for high quality and performance, we pour all our experience into creating beautifully designed, practical products like our trendsetting range. Strikingly elegant in every table setting, every piece helps transform simple gatherings into stylish occasions. Making whatever you're doing simpler, smarter and better. As dependable as they are desirable, you can trust our products always to perform beautifully. \t\t\t\t    \t \t\t\t\t\t From the Manufacturer The Classic Tea Set comes in two sizes – with a Carafe and 4 Classic Mugs, and the second with a Carafe and 6 Classic Mugs. Perfect for your daily dose of chai, coffee, iced tea or even beer. Usage and Care Borosil Carafe can be used directly on the flame, hot plate, microwave or oven When removing the Carafe from the flame, do not immediately place the hot Carafe on wet or cold surfaces. Use a coaster instead Wipe outside dry before use If using directly on the flame, ensure that the flame is restricted to the glass base, and doesn’t reach the plastic handle. Do not use abrasive scouring agents for cleaning. Clean with soap and sponge and wipe dry Can be used in a dishwasher.",
#  "AMERICAN CREW Men's Polyester Polo American crew presents the active wear collection, 100 percent polyester sports polo with contrast colour panels. Fall in love with the two-tone t-shirt, with super-soft hand feel. Your skin will love the feel of this t-shirt as it is fashioned using the material that is famous for comfort - fine polyester. You can wear this t-shirt for any sporting activity as it's made from a dry fit material or you can pair it with jeans or shorts to give you casual look. Made in India.",
#  "The Wealth of Nations Review ''(Narrator) Edwards enunciates with unusual clarity, which helps with a book published in 1776.'' --Talking Book Review''Adam Smith's enormous authority resides, in the end, in the same property that we discover in Marx: not in any ideology, but in an effort to see to the bottom of things.'' --Robert L. Heilbroner, author of The Worldly Philosophers''The Wealth of Nations is no defender of 'greed is good' economics; the author's humanity and benevolence tint every page.'' --Eamonn Butler, Director of the Adam Smith Institute''Simply the best book on political economy ever written. It is a genuine 'breakthrough' book whose magisterial scope and synthesis have not been surpassed.'' --Dr. Razeen Sally, senior lecturer, London School of Economics, and codirector of the European Center for Political Economy \t\t\t\t    \t \t\t\t\t\t About the Author Adam Smith (1723-1790) was born in a small village in Kirkcaldy, Scotland. He entered the University of Glasgow at age fourteen and later attended Balliol College at Oxford. After lecturing for a period, he held several teaching positions at the University of Glasgow. His greatest achievement was writing The Wealth of Nations, a five-book series that sought to reveal the true causes of prosperity and which established him as the father of contemporary economic thought.",
#  'Classic Mosquito Net Classic Foldable Mosquito Net (Single Bed)With Free Saviours - (Pink) Classic mosquito net is made of polyester fabric and finest mesh which ensures super quality and restricts flies and mosquitoes from entering the net, It even prevents and protects your body from mosquito and insect bites; It furthermore assures you an insect free milieu to enjoy a sound sleep  This mosquito net is stylish yet spacious which is specifically designed keeping in the changing needs of the consumer, It comprises of 1 zipper gate which makes you easy to get in and out  Light weighted net makes it convenient for users to take it along while traveling, It\'s easy to fold provision makes it all the more hassle free  It is easy to put on and equally easy to remove; Easy to wash, it offers a clean environment top sleep in  Size: 200x130x145 cm Classic mosquito net is unique, stylish and hassle free mosquito net that helps you stay away from the mosquito and insect bites. Prevent your loved once from dreadful disease like malaria, filaria and dengue. Made from Spring steel technology frames which make it flexible and safe to sleep in. There is convenient zipper on one side for easy entry and exit. No need of separate rods to hang the net as it comes with a strong flexible frame which fixes easily. The net can be folded and easily stored in a carry bag therefore space saver too. One can carry this net while travelling and camping as it is light in weight and does not take much space and washable as well. During summers the one can use it on terrace too. You can see its folding instruction on Youtube "https://www.youtube.com/watch?v=OEnIE6ICVLU "',
#  'Royaloak Neptune Computer Table (Black) Royaloak Neptune computer table is made up of HDF with melamine finish. Contemporary design. Ample storage with stool. It comes with stool for comfortable seating.',
#  ...]

# %%
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text

print(tf.__version__)

bert_preprocess = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/1")
bert_encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/3")

text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name = "text")
preprocessed_inputs = bert_preprocess(text_input)
encoded_outputs = bert_encoder(preprocessed_inputs)

encoded_outputs['pooled_output']
# Out:
# 2.10.1
# <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'keras_layer_3')>

# %%
x_train[1].dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 x_train[1].dtype
#
# AttributeError: 'str' object has no attribute 'dtype'

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(min_df=0, lowercase=False)
vectorizer.fit(x_train)
vectorizer.vocabulary_
# Out:
# {'Havells': 23437,
#  'V3': 45593,
#  'Yurbo': 48127,
#  '450mm': 4479,
#  'Pedestal': 34576,
#  'Fan': 20135,
#  'Black': 11539,
#  'India': 25029,
#  'Limited': 28328,
#  'is': 62604,
#  'leading': 63437,
#  'Fast': 20201,
#  'Moving': 31243,
#  'Electrical': 18773,
#  'Goods': 22258,
#  'FMEG': 19889,
#  'Company': 14933,
#  'and': 49408,
#  'major': 64290,
#  'power': 68639,
#  'distribution': 56150,
#  'equipment': 57514,
#  'manufacturer': 64419,
#  'with': 77932,
#  'strong': 73967,
#  'global': 59803,
#  'presence': 68817,
#  'enjoys': 57334,
#  'enviable': 57448,
#  'market': 64464,
#  'dominance': 56288,
#  'across': 48724,
#  'wide': 77803,
#  'spectrum': 73234,
#  'of': 66552,
#  'products': 69040,
#  'including': 61781,
#  'Industrial': 25100,
#  'Domestic': 17675,
#  'Circuit': 14424,
#  'Protection': 36013,
#  'Devices': 17207,
#  'Cables': 13329,
#  'Wires': 47418,
#  'Motors': 31198,
#  'Fans': 20151,
#  'Modular': 30926,
#  'Switches': 42866,
#  'Home': 23933,
#  'Appliances': 9246,
#  'Air': 8527,
#  'Conditioners': 15082,
#  'Electric': 18771,
#  'Water': 46961,
#  'Heaters': 23553,
#  'Power': 35533,
#  'Capacitors': 13560,
#  'Luminaires': 28716,
#  'for': 58989,
#  'Commercial': 14894,
#  'Applications': 9250,
#  'Think': 44002,
#  'Grow': 22544,
#  'Rich': 37953,
#  'Lectures': 28012,
#  'by': 51892,
#  'Napoleon': 31928,
#  'Hill': 23782,
#  'MP3': 29301,
#  'Urbaano': 45497,
#  'Belo': 11151,
#  'Lace': 27698,
#  'Bikini': 11412,
#  'Set': 40296,
#  'Red': 37366,
#  'Pack': 34064,
#  'bikini': 50933,
#  'set': 72002,
#  'in': 61677,
#  'simple': 72450,
#  'stunning': 74030,
#  'triangle': 75894,
#  'makes': 64304,
#  'this': 75222,
#  'standout': 73541,
#  'halter': 60351,
#  'top': 75548,
#  'panty': 67346,
#  'style': 74046,
#  'that': 75089,
#  'can': 52059,
#  'be': 50625,
#  'tied': 75345,
#  'at': 50056,
#  'both': 51366,
#  'the': 75096,
#  'sides': 72382,
#  'according': 48638,
#  'to': 75454,
#  'your': 78361,
#  'size': 72541,
#  'Be': 10978,
#  'Stunner': 42370,
#  'Leoxsys': 28144,
#  'LEO': 27479,
#  '300N': 3447,
#  '3G': 4042,
#  'AD': 7443,
#  'Multifunctional': 31352,
#  '300mbps': 3465,
#  'ADSL': 7497,
#  'modem': 65298,
#  'Router': 38300,
#  '2G': 3257,
#  'CDMA': 12755,
#  'USB': 45117,
#  'printer': 68936,
#  'server': 71987,
#  'ADSL2': 7498,
#  'Modem': 30903,
#  '300M': 3440,
#  '4G': 4683,
#  'Print': 35790,
#  'FTP': 19988,
#  'All': 8695,
#  'One': 33070,
#  'Device': 17205,
#  '300Mbps': 3443,
#  'Wireless': 47414,
#  'NAT': 31586,
#  'port': 68509,
#  'Switch': 42857,
#  'Server': 40277,
#  'work': 78041,
#  'as': 49905,
#  'Repeater': 37657,
#  'Booster': 11901,
#  'connect': 53844,
#  'other': 66919,
#  'router': 71153,
#  'wirelessly': 77915,
#  'boost': 51323,
#  'enhance': 57315,
#  'WiFi': 47259,
#  'Signal': 40851,
#  'instantly': 62200,
#  '4GHz': 4689,
#  'IEEE802': 24380,
#  '11b': 737,
#  'up': 76712,
#  'data': 54980,
#  'transfer': 75748,
#  'rates': 69783,
#  'Compatible': 14959,
#  'all': 49182,
#  'Indian': 25039,
#  'ISP': 24679,
#  'like': 63715,
#  'BSNL': 10435,
#  'MTNL': 29395,
#  'AIRTEL': 7570,
#  'TATA': 43032,
#  'INDICOM': 24512,
#  'Major': 29677,
#  'Service': 40283,
#  'providers': 69261,
#  'firmware': 58637,
#  'has': 60520,
#  'per': 67722,
#  'installed': 62185,
#  'settings': 72016,
#  'its': 62665,
#  'plug': 68277,
#  'play': 68197,
#  'internet': 62360,
#  'access': 48593,
#  'WAN': 46477,
#  'Failover': 20091,
#  'support': 74335,
#  'which': 77732,
#  'guarantees': 60195,
#  'sustained': 74442,
#  'Internet': 25393,
#  'connection': 53850,
#  'Supports': 42680,
#  'Storage': 42196,
#  'Make': 29688,
#  'Network': 32183,
#  'sharing': 72108,
#  'Local': 28494,
#  'wireless': 77913,
#  'High': 23747,
#  'Gain': 21644,
#  'dBi': 54880,
#  'Antenna': 9102,
#  'speed': 73244,
#  'ideal': 61402,
#  'video': 77147,
#  'streaming': 73879,
#  'Share': 40457,
#  'freedom': 59193,
#  'The': 43890,
#  'one': 66661,
#  'device': 55610,
#  'providing': 69263,
#  'users': 76834,
#  'high': 60823,
#  'upto': 76769,
#  '24Mbps': 2878,
#  '28Mbps': 3174,
#  '75G': 6188,
#  'LTE': 27642,
#  'Usb': 45534,
#  '802': 6437,
#  '11n': 752,
#  'speeds': 73255,
#  'supports': 74348,
#  'backup': 50393,
#  'ensure': 57371,
#  '24x7': 2915,
#  'uninterrupted': 76510,
#  'time': 75379,
#  'With': 47436,
#  'multifunction': 65669,
#  'share': 72104,
#  'printers': 68938,
#  'storage': 73786,
#  'over': 67030,
#  'local': 63879,
#  'network': 66063,
#  'Mamma': 29739,
#  'Maternity': 30077,
#  'Denim': 16979,
#  'Jeans': 25966,
#  'Denims': 16986,
#  'Complement': 14983,
#  'Your': 48100,
#  'Trendy': 44606,
#  'Tunics': 44827,
#  'Tops': 44351,
#  'These': 43970,
#  'from': 59278,
#  'House': 24095,
#  'Featuring': 20279,
#  'Roll': 38180,
#  'Over': 33390,
#  'Panel': 34219,
#  'This': 44024,
#  'Pair': 34138,
#  'Of': 32966,
#  'Trousers': 44713,
#  'Promises': 35958,
#  'Maximum': 30157,
#  'Comfort': 14863,
#  'And': 8964,
#  'Soft': 41410,
#  'Feel': 20302,
#  'Courtesy': 15556,
#  'Skin': 41073,
#  'Friendly': 21085,
#  'Fabric': 20046,
#  'Features': 20261,
#  'Stretchable': 42286,
#  'Fit': 20550,
#  'Fashionable': 20192,
#  'Specially': 41669,
#  'Designed': 17118,
#  'For': 20837,
#  'Growing': 22545,
#  'Belly': 11149,
#  'Provides': 36052,
#  'Support': 42664,
#  'Adjustable': 8288,
#  'Waist': 46792,
#  'Band': 10736,
#  'To': 44243,
#  'Suit': 42520,
#  'Pre': 35628,
#  'Post': 35472,
#  'Pregnancy': 35657,
#  'Size': 41021,
#  'At': 9656,
#  'Hips': 23820,
#  'Fitted': 20560,
#  'Thighs': 43989,
#  'Narrow': 31954,
#  'Leg': 28031,
#  'Opening': 33122,
#  'Blend': 11614,
#  'CottonSIZE': 15502,
#  'TIP': 43166,
#  'Kindly': 26967,
#  'Check': 14142,
#  'Guide': 22605,
#  'Measurements': 30276,
#  'Before': 11082,
#  'Selecting': 40154,
#  'Is': 25541,
#  'SizeBrand': 41024,
#  'InformationPregnancy': 25148,
#  'Big': 11389,
#  'Change': 14034,
#  'Every': 19349,
#  'Woman': 47475,
#  'Life': 28259,
#  'Women': 47479,
#  'Face': 20060,
#  'Many': 29873,
#  'Dresses': 17839,
#  'Issue': 25582,
#  'During': 18011,
#  'So': 41360,
#  'Our': 33330,
#  'Would': 47593,
#  'Love': 28632,
#  'Help': 23618,
#  'Them': 43916,
#  'Problem': 35847,
#  'Complete': 14987,
#  'Nursing': 32615,
#  'Apparels': 9222,
#  'WhiteRay': 47220,
#  'Round': 38291,
#  'Hanging': 23255,
#  'light': 63689,
#  'Sure': 42696,
#  'architectural': 49766,
#  'attributes': 50145,
#  'home': 60952,
#  'or': 66791,
#  'office': 66585,
#  'ceiling': 52388,
#  'lamp': 63281,
#  'latest': 63358,
#  'collection': 53312,
#  'Whiteray': 47231,
#  'great': 60081,
#  'choice': 52777,
#  'Made': 29522,
#  'premium': 68788,
#  'quality': 69513,
#  'material': 64573,
#  'used': 76821,
#  'purely': 69412,
#  'charming': 52604,
#  'decorative': 55144,
#  'piece': 68008,
#  'amazingly': 49294,
#  'beautiful': 50672,
#  'lighting': 63702,
#  'option': 66781,
#  'been': 50713,
#  'created': 54501,
#  'utility': 76853,
#  'In': 24923,
#  'addition': 48797,
#  'lovely': 64035,
#  'structure': 73990,
#  'will': 77838,
#  'surely': 74367,
#  'attract': 50133,
#  'lot': 64003,
#  'onlookers': 66674,
#  'Further': 21223,
#  'pretty': 68869,
#  'enrich': 57355,
#  'look': 63961,
#  'any': 49581,
#  'space': 73128,
#  'giving': 59741,
#  'it': 62642,
#  'visually': 77250,
#  'delightful': 55291,
#  'approach': 49699,
#  'Invest': 25466,
#  'make': 64296,
#  'plush': 68309,
#  'prettier': 68867,
#  'Rupa': 38416,
#  'Jon': 26136,
#  'Boys': 12025,
#  'Cotton': 15496,
#  'Boxer': 12007,
#  'iBall': 61316,
#  'Soundwave': 41567,
#  'Channel': 14042,
#  'Multimedia': 31359,
#  'Speakers': 41653,
#  'Product': 35873,
#  'Description': 17068,
#  'Soundwave2': 41568,
#  'Compact': 14926,
#  'yet': 78329,
#  'powerful': 68646,
#  'speakers': 73182,
#  'search': 71739,
#  'music': 65750,
#  'come': 53408,
#  'sound': 73096,
#  'producing': 69028,
#  'capacity': 52131,
#  'compact': 53518,
#  'design': 55491,
#  'them': 75122,
#  'portable': 68514,
#  'nature': 65909,
#  'ends': 57267,
#  'multimedia': 65679,
#  'are': 49784,
#  'easy': 56783,
#  'carry': 52243,
#  'thanks': 75086,
#  'their': 75120,
#  'lightweight': 63712,
#  'feature': 58360,
#  'while': 77736,
#  'stylish': 74055,
#  'distinctive': 56124,
#  'sturdy': 74042,
#  'body': 51229,
#  'offers': 66584,
#  'higher': 60826,
#  'durability': 56613,
#  'powered': 68643,
#  'using': 76840,
#  'so': 72918,
#  'you': 78349,
#  'comfortably': 53431,
#  'listen': 63805,
#  'favourite': 58327,
#  'audio': 50158,
#  'individual': 61873,
#  'have': 60556,
#  'integrated': 62259,
#  'another': 49518,
#  'inch': 61718,
#  'drivers': 56499,
#  'Better': 11275,
#  'throw': 75292,
#  'compatibility': 53553,
#  'response': 70662,
#  'frequency': 59219,
#  '90Hz': 6868,
#  '20kHz': 2528,
#  'these': 75176,
#  'deliver': 55300,
#  'cutting': 54835,
#  'edge': 56839,
#  'technology': 74885,
#  'ensures': 57373,
#  'there': 75151,
#  'lesser': 63577,
#  'distortion': 56134,
#  'get': 59655,
#  'every': 57691,
#  'acoustic': 48701,
#  'utmost': 76859,
#  'clarity': 52961,
#  'volume': 77307,
#  'controller': 54083,
#  'increase': 61810,
#  'decrease': 55152,
#  'Since': 40943,
#  'mm': 65237,
#  'jack': 62678,
#  'use': 76804,
#  'PC': 33598,
#  'laptop': 63327,
#  'tablet': 74665,
#  'On': 33065,
#  'Go': 22158,
#  'Usage': 45526,
#  'If': 24787,
#  'lover': 64037,
#  'travel': 75822,
#  'frequently': 59221,
#  'then': 75131,
#  'ohm': 66609,
#  'impedance': 61584,
#  'output': 66994,
#  'superior': 74285,
#  'standard': 73532,
#  'sure': 74366,
#  'reach': 69822,
#  'corner': 54221,
#  'room': 71097,
#  'effectively': 56896,
#  'good': 59907,
#  'value': 76929,
#  'money': 65395,
#  'product': 69029,
#  'if': 61443,
#  'want': 77427,
#  'wherever': 77728,
#  'go': 59851,
#  'Not': 32513,
#  'only': 66675,
#  'watching': 77519,
#  'movies': 65596,
#  'playing': 68215,
#  'games': 59476,
#  'well': 77668,
#  'Other': 33313,
#  'Specifications': 41681,
#  'simply': 72462,
#  'weigh': 77646,
#  '408': 4268,
#  'dimensions': 55809,
#  '20': 2261,
#  '10': 278,
#  'cm': 53150,
#  'channel': 52550,
#  'configuration': 53790,
#  '60': 5485,
#  'dB': 54872,
#  'signal': 72399,
#  'noise': 66221,
#  'ratio': 69789,
#  '65': 5732,
#  'separation': 71948,
#  'From': 21110,
#  'Manufacturer': 29865,
#  'Ultra': 45201,
#  'Portable': 35430,
#  'Superior': 42634,
#  'Sound': 41554,
#  'Output': 33368,
#  'buff': 51719,
#  'miss': 65185,
#  'system': 74626,
#  'lets': 63585,
#  'enjoy': 57327,
#  'whether': 77730,
#  'on': 66651,
#  'move': 65586,
#  'hosting': 61074,
#  'party': 67472,
#  'stereo': 73674,
#  'not': 66289,
#  'ultra': 76224,
#  'but': 51855,
#  'an': 49365,
#  'Ohms': 32999,
#  'they': 75182,
#  'give': 59735,
#  'exceptionally': 57772,
#  'impressive': 61651,
#  'along': 49232,
#  'unmatched': 76561,
#  'irresistible': 62587,
#  'price': 68891,
#  'tag': 74691,
#  'such': 74160,
#  'varied': 76968,
#  'features': 58362,
#  'offer': 66579,
#  'complete': 53605,
#  'Great': 22428,
#  'Compatibility': 14954,
#  'Bundle': 12420,
#  'connectivity': 53855,
#  'never': 66093,
#  'problem': 68988,
#  'readily': 69843,
#  'compatible': 53557,
#  'range': 69737,
#  'devices': 55612,
#  'gaming': 59477,
#  'via': 77120,
#  'cable': 51927,
#  'two': 76166,
#  '90': 6833,
#  '20000': 2264,
#  'Hz': 24294,
#  'impeccable': 61582,
#  'Popular': 35413,
#  'controls': 54087,
#  'best': 50842,
#  'line': 63751,
#  'instant': 62197,
#  'adjustment': 48845,
#  'Buy': 12524,
#  'extremely': 58034,
#  'soundwave2': 73112,
#  'online': 66673,
#  'booming': 51320,
#  'anytime': 49589,
#  'anywhere': 49592,
#  'Type': 44928,
#  'speaker': 73178,
#  'Configuration': 15107,
#  'Total': 44374,
#  'RMS': 36735,
#  'Frequency': 21052,
#  'Response': 37768,
#  'Satellite': 39754,
#  'Impedance': 24879,
#  'Noise': 32432,
#  'Ratio': 37176,
#  'Easy': 18557,
#  'Connectivity': 15155,
#  'Audio': 9749,
#  'Jack': 25808,
#  'Additional': 8254,
#  'satellite': 71466,
#  'driver': 56495,
#  'unit': 76523,
#  'PAffy': 33592,
#  'Steel': 42062,
#  'Multi': 31322,
#  'Utility': 45564,
#  'Shoe': 40643,
#  'Rack': 36902,
#  'Shelf': 40534,
#  'Color': 14787,
#  'Colour': 14813,
#  'name': 65839,
#  'grey': 60105,
#  'introductions': 62447,
#  'paffy': 67236,
#  'tier': 75346,
#  'dustproof': 56638,
#  'shoe': 72226,
#  'rack': 69634,
#  'designed': 55504,
#  'provide': 69257,
#  'solution': 73028,
#  'favorite': 58318,
#  'footwear': 58987,
#  'It': 25589,
#  'constructed': 53946,
#  'out': 66940,
#  'metal': 64887,
#  'pipes': 68081,
#  'non': 66236,
#  'woven': 78120,
#  'fabrics': 58103,
#  'plastic': 68172,
#  'connectors': 53858,
#  'hold': 60925,
#  'numerous': 66388,
#  'pairs': 67270,
#  'shoes': 72230,
#  'innovative': 62094,
#  'saving': 71504,
#  'placed': 68133,
#  'cubby': 54678,
#  'closet': 53103,
#  'mudroom': 65632,
#  'busy': 51852,
#  'entryway': 57437,
#  'keep': 62980,
#  'accessories': 48602,
#  'accessible': 48598,
#  'lattices': 63365,
#  'provides': 69262,
#  'enough': 57350,
#  'concise': 53718,
#  'nice': 66129,
#  'looking': 63966,
#  'does': 56254,
#  'occupy': 66510,
#  'too': 75532,
#  'much': 65627,
#  'keeps': 62983,
#  'clean': 52998,
#  'single': 72485,
#  'place': 68131,
#  'easily': 56776,
#  'locate': 63885,
#  'greatly': 60084,
#  'save': 71498,
#  'searching': 71743,
#  'eye': 58050,
#  'catching': 52325,
#  'pattern': 67560,
#  'item': 62658,
#  'house': 61109,
#  'specifications': 73211,
#  'Material': 30065,
#  'pp': 68662,
#  'layers': 63411,
#  'pipe': 68078,
#  'diameter': 55692,
#  '47': 4564,
#  '2cm': 3337,
#  'Dimensions': 17371,
#  '23': 2747,
#  '11': 632,
#  '63': 5675,
#  '58': 5205,
#  '30': 3422,
#  '160': 1453,
#  'Weight': 47081,
#  '4lbs': 4771,
#  '1550g': 1345,
#  'package': 67198,
#  'includes': 61778,
#  'tiers': 75348,
#  'Royaloak': 38324,
#  'Berlin': 11227,
#  'Four': 20948,
#  'Seater': 40064,
#  'Dining': 17391,
#  'Table': 43400,
#  'Brown': 12297,
#  'Royal': 38319,
#  'Oak': 32857,
#  'furniture': 59396,
#  'experience': 57904,
#  'amazing': 49293,
#  'international': 62355,
#  'collections': 53313,
#  'elegant': 56996,
#  'aesthetic': 48973,
#  'outdoor': 66950,
#  'sourced': 73117,
#  'nationally': 65897,
#  'internationally': 62358,
#  'globe': 59809,
#  'Decades': 16763,
#  'expertise': 57919,
#  'means': 64682,
#  'today': 75468,
#  'proud': 69249,
#  'bring': 51596,
#  'biggest': 50924,
#  'country': 54342,
#  'sofas': 72969,
#  'living': 63851,
#  'bed': 50688,
#  'unbeatable': 76279,
#  'service': 71992,
#  'unique': 76518,
#  'remarkable': 70360,
#  'Teconica': 43683,
#  'KL': 26432,
#  '5000': 4821,
#  'Full': 21158,
#  'HD': 22828,
#  'Action': 8187,
#  'Camera': 13450,
#  '170': 1628,
#  'Wide': 47270,
#  'Angle': 9014,
#  'Lens': 28120,
#  'Accessories': 8101,
#  'Assorted': 9607,
#  'water': 77521,
#  'resistant': 70614,
#  'casing': 52282,
#  'allows': 49214,
#  'film': 58545,
#  'fascinating': 58258,
#  'sports': 73357,
#  'Multiple': 31364,
#  'photo': 67939,
#  'shooting': 72238,
#  'modes': 65312,
#  'Single': 40963,
#  'shot': 72272,
#  'Snapper': 41310,
#  'recording': 70015,
#  'formats': 59069,
#  '1080P': 506,
#  '720P': 6097,
#  'WVGA': 46760,
#  'meters': 64912,
#  'under': 76331,
#  'definition': 55218,
#  'screen': 71667,
#  'displays': 56063,
#  'replays': 70474,
#  'videos': 77156,
#  'recorded': 70012,
#  'HDMI': 22847,
#  'function': 59346,
#  'web': 77615,
#  'camera': 52025,
#  'Detachable': 17158,
#  'battery': 50595,
#  'replace': 70464,
#  'prolongs': 69119,
#  'cameras': 52032,
#  'life': 63662,
#  'Micro': 30577,
#  'SD': 38644,
#  'Card': 13622,
#  'Class': 14492,
#  'Above': 8030,
#  '32GB': 3655,
#  'Technical': 43658,
#  'Chipset': 14274,
#  'NTK96650': 31795,
#  'AR0330': 7763,
#  'Liquid': 28398,
#  'Crystal': 15806,
#  'Display': 17519,
#  'LCD': 27428,
#  '5LTPS': 5315,
#  '170Â': 1642,
#  'angle': 49449,
#  'lens': 63562,
#  'Resolution': 37750,
#  'Videos': 46169,
#  'Recorded': 37334,
#  '1920': 1930,
#  '1080': 504,
#  '30FPS': 3517,
#  '1280': 891,
#  '720': 6089,
#  '60FPS': 5561,
#  'VGA': 45696,
#  '848': 6579,
#  '480': 4594,
#  'QVGA': 36312,
#  '640': 5705,
#  'Video': 46162,
#  'Format': 20893,
#  'MOV': 29290,
#  'Compressed': 15021,
#  '264': 3062,
#  'Photos': 34866,
#  '12M': 946,
#  '8M': 6734,
#  '5M': 5316,
#  'max': 64628,
#  'Design': 17107,
#  'Thinking': 44010,
#  'Strategic': 42251,
#  'Innovation': 25207,
#  'Back': 10557,
#  'Cover': 15567,
#  'BUSINESS': 10490,
#  'AS': 7795,
#  'USUAL': 45147,
#  'IS': 24655,
#  'DONE': 16360,
#  'FOR': 19917,
#  'As': 9514,
#  'technological': 74881,
#  'innovation': 62092,
#  'accelerated': 48571,
#  'people': 67711,
#  'communities': 53509,
#  'organizations': 66854,
#  'become': 50684,
#  'more': 65470,
#  'connected': 53846,
#  'than': 75082,
#  'ever': 57686,
#  'before': 50724,
#  'We': 47013,
#  'talk': 74723,
#  'expect': 57884,
#  'disruption': 56081,
#  'changed': 52543,
#  'way': 77564,
#  'consumers': 53972,
#  'do': 56229,
#  'business': 51836,
#  'watch': 77515,
#  'iPads': 61343,
#  'TV': 43363,
#  'don': 56296,
#  'believe': 50771,
#  'hype': 61268,
#  'shop': 72241,
#  'stores': 73797,
#  'eat': 56786,
#  'junk': 62884,
#  'ingredients': 62016,
#  'what': 77705,
#  'we': 77577,
#  'when': 77718,
#  'environment': 57454,
#  'traditional': 75693,
#  'ways': 77572,
#  'running': 71238,
#  'just': 62893,
#  'won': 77990,
#  'anymore': 49583,
#  'Enter': 19092,
#  'thinking': 75207,
#  'explains': 57931,
#  'how': 61129,
#  'about': 48502,
#  'creative': 54507,
#  'solutions': 73029,
#  'solve': 73030,
#  'complex': 53611,
#  'problems': 68989,
#  'Through': 44077,
#  'real': 69855,
#  'examples': 57751,
#  'shows': 72309,
#  'applied': 49671,
#  'different': 55745,
#  'industries': 61905,
#  'contexts': 54023,
#  'An': 8924,
#  'essential': 57589,
#  'guide': 60219,
#  'seeking': 71823,
#  'solving': 73035,
#  'tool': 75535,
#  'methodology': 64920,
#  'transform': 75755,
#  'companies': 53526,
#  'cultures': 54717,
#  'YOU': 47942,
#  'LL': 27545,
#  'LEARN': 27450,
#  'How': 24112,
#  'apply': 49675,
#  'long': 63941,
#  'planningWhy': 68159,
#  'future': 59419,
#  'leader': 63434,
#  'needs': 65991,
#  'thinkerThe': 75205,
#  'principles': 68931,
#  'redefine': 70067,
#  'managementDesign': 64344,
#  'framework': 59171,
#  'tailored': 74700,
#  'eight': 56931,
#  'key': 63003,
#  'challenges': 52510,
#  'businesses': 51837,
#  'faceHow': 58113,
#  'create': 54499,
#  'culture': 54715,
#  'within': 77943,
#  'companyHiring': 53532,
#  'thinkers': 75206,
#  'Discover': 17469,
#  'build': 51732,
#  'into': 62421,
#  'organization': 66851,
#  'DNA': 16337,
#  'Revolutionize': 37883,
#  'greatest': 60083,
#  'About': 8027,
#  'Author': 9814,
#  'IDRIS': 24367,
#  'MOOTEE': 29268,
#  'CEO': 12773,
#  'Idea': 24754,
#  'Couture': 15564,
#  'rm': 71005,
#  'ofces': 66569,
#  'San': 39627,
#  'Francisco': 20989,
#  'Shanghai': 40431,
#  'Toronto': 44363,
#  'London': 28545,
#  'Dubai': 17924,
#  'Mexico': 30538,
#  'City': 14451,
#  'He': 23478,
#  'worked': 78046,
#  'clients': 53047,
#  'Amex': 8857,
#  'Burberry': 12432,
#  'BMW': 10303,
#  'Boeing': 11780,
#  'Cisco': 14435,
#  'De': 16717,
#  'Beers': 11078,
#  'Kraft': 27180,
#  'Nike': 32329,
#  'Samsung': 39613,
#  'Pepsi': 34658,
#  'expert': 57917,
#  'Idris': 24783,
#  'speaks': 73184,
#  'strategic': 73859,
#  'developing': 55602,
#  'foresight': 59031,
#  'model': 65289,
#  'through': 75287,
#  'application': 49668,
#  'also': 49249,
#  'author': 50193,
#  'Minute': 30746,
#  'Brand': 12080,
#  'Strategist': 42255,
#  'published': 69333,
#  'Wiley': 47312,
#  'Aristo': 9389,
#  'Multipurpose': 31371,
#  'Drawer': 17810,
#  'Plastic': 35131,
#  'Chest': 14187,
#  'Organizer': 33241,
#  'Large': 27826,
#  'multipurpose': 65700,
#  'drawer': 56437,
#  'comes': 53416,
#  ...}

# %%
# Out:
# <KerasTensor: shape=(768,) dtype=float32 (created by layer 'tf.__operators__.getitem_2')>

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

#Neural network
layer = tf.keras.layers.Dropout(0.1, name='dropout') (encoded_outputs['pooled_output'])
layer= tf.keras.layers.Dense(4, activation='sigmoid', name="output")(layer)

#Construct the final model
model = tf.keras.Model(inputs=[text_input], outputs=[layer])


# model = Sequential()

# model.add(Dense(60, input_shape = (1,), activation = "relu"))
# model.add(Dense(15, activation = "relu"))
# model.add(Dropout(0.2))
# model.add(Dense(4, activation = "sigmoid"))
# model.compile(Adam(learning_rate = 0.01), "categorical_crossentropy", metrics = [tf.keras.metrics.BinaryAccuracy(name = 'Accuracy'),
#                        tf.keras.metrics.Precision(name = 'Precision'), 
#                        tf.keras.metrics.Recall(name = 'Recall')])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text (InputLayer)              [(None,)]            0           []
#
#  keras_layer_2 (KerasLayer)     {'input_word_ids':   0           ['text[0][0]']
#                                 (None, 128),
#                                  'input_mask': (Non
#                                 e, 128),
#                                  'input_type_ids':
#                                 (None, 128)}
#
#  keras_layer_3 (KerasLayer)     {'sequence_output':  109482241   ['keras_layer_2[0][0]',
#                                  (None, 128, 768),                'keras_layer_2[0][1]',
#                                  'pooled_output': (               'keras_layer_2[0][2]']
#                                 None, 768),
#                                  'encoder_outputs':
#                                  [(None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768)],
#                                  'default': (None,
#                                 768)}
#
#  dropout (Dropout)              (None, 768)          0           ['keras_layer_3[0][13]']
#
#  output (Dense)                 (None, 4)            3076        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 109,485,317
# Trainable params: 3,076
# Non-trainable params: 109,482,241
# __________________________________________________________________________________________________

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(), optimizer='adam',
              metrics=[tf.keras.metrics.BinaryAccuracy(name = 'Accuracy'),
                       tf.keras.metrics.Precision(name = 'Precision'), 
                       tf.keras.metrics.Recall(name = 'Recall')])

# %%
# y_train=np.asarray(y_train).astype(float)

model.fit(x_train, y_train, epochs = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 # y_train=np.asarray(y_train).astype(float)
# ----> 3 model.fit(x_train, y_train, epochs = 1)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101 ctx.ensure_initialized()
# --> 102 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type float).

# %%
y_train.dtype
# Out:
# dtype('int32')

# %%
y_train = np.asarray(y_train.astype(int))

# %%
model.fit(x_train, y_train, epochs=1, verbose=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 model.fit(x_train, y_train, epochs=1, verbose=1)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101 ctx.ensure_initialized()
# --> 102 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type float).
