# %% [markdown]
# # Importing library and data

# %%
pip install tensorflow_text

# %%
import tensorflow as tf
tf.__version__

# %%
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text

# %%
import pandas as pd

dt = pd.read_csv('./datasets/ecommerceDataset.csv')
dt.head(10)
# Out:
#       Labels                                               Text
# 0  Household  Paper Plane Design Framed Wall Hanging Motivat...
# 1  Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 2  Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 3  Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 4  Household  Incredible Gifts India Wooden Happy Birthday U...
# 5  Household  Pitaara Box Romantic Venice Canvas Painting 6m...
# 6  Household  Paper Plane Design Starry Night Vangoh Wall Ar...
# 7  Household  Pitaara Box Romantic Venice Canvas Painting 6m...
# 8  Household  SAF 'Ganesh Modern Art Print' Painting (Synthe...
# 9  Household  Paintings Villa UV Textured Modern Art Print F...

# %% [markdown]
# ## **Data preprocessing**
# ### *Getting all categories*

# %%
categories = dt['Labels'].unique()
print(categories)
# Out:
# ['Household' 'Books' 'Clothing & Accessories' 'Electronics']

# %%
dt.groupby('Labels').describe()
# Out:
#                          Text
#                         count unique
# Labels
# Books                   11820   6256  \
# Clothing & Accessories   8670   5674
# Electronics             10621   5308
# Household               19313  10564
#
#
#                                                                       top freq
# Labels
# Books                   Think & Grow Rich About the Author NAPOLEON HI...   30
# Clothing & Accessories  Diverse Men's Formal Shirt Diverse is a wester...   23
# Electronics             HP 680 Original Ink Advantage Cartridge (Black...   26
# Household               Nilkamal Series-24 Chest of Drawers (Cream Tra...   13

# %% [markdown]
# ### *Handling dataframes*

# %%
df_accessories = dt[dt['Labels'] == 'Clothing & Accessories']
df_accessories.head(10)
df_accessories.shape
# Out:
# (8671, 2)

# %%
df_books = dt[dt['Labels'] == 'Books']
df_books.shape
# Out:
# (11820, 2)

# %%
df_household = dt[dt['Labels'] == 'Household']
df_household.shape
# Out:
# (19313, 2)

# %%
df_elec = dt[dt['Labels'] == 'Electronics']
df_elec.shape
# Out:
# (10621, 2)

# %% [markdown]
# ### ***Balancing dataframes***

# %%
df_books_downsample = df_books.head(df_accessories.shape[0])
df_books_downsample.shape
# Out:
# (8671, 2)

# %%
df_household_downsample = df_household.head(df_accessories.shape[0])
df_household_downsample.shape
# Out:
# (8671, 2)

# %%
df_elec_downsample = df_elec.head(df_accessories.shape[0])
df_elec_downsample.shape
df_elec_downsample.head()
# Out:
#             Labels                                               Text
# 39804  Electronics  Dell 19.5V-3.34AMP 65W Laptop Adapter (Without...
# 39805  Electronics  Bluetooth Dongle USB CSR 4.0 Adapter Receiver ...
# 39806  Electronics  Wi-Fi Receiver 300Mbps, 2.4GHz, 802.11b/g/n US...
# 39807  Electronics  SanDisk 64GB Class 10 microSDXC Memory Card wi...
# 39808  Electronics  Gizga Essentials Laptop Power Cable Cord- 3 Pi...

# %% [markdown]
# ### ***Merging dataframes***

# %%
dfs_array = [df_accessories, df_books_downsample, df_household_downsample, df_elec_downsample]
df_merged = pd.concat(dfs_array)
df_merged[df_merged['Labels'] == 'Household']
# Out:
#          Labels                                               Text
# 0     Household  Paper Plane Design Framed Wall Hanging Motivat...
# 1     Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 2     Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 3     Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 4     Household  Incredible Gifts India Wooden Happy Birthday U...
# ...         ...                                                ...
# 8666  Household  Glync 5W LED Recessed Spot Light Ceiling Downl...
# 8667  Household  Philips AstraPrime 10-Watt Recessed LED Panel ...
# 8668  Household  D'MakTM LED Ceiling COB Spot Light - 3 Watt - ...
# 8669  Household  Philips AstraPrime 5-Watt Recessed LED Panel C...
# 8670  Household  Philips Astra Prime 22-Watt LED Panel Light (C...
#
# [8671 rows x 2 columns]

# %% [markdown]
# ### ***Adding 'type' column***

# %%
df_merged
# Out:
#                        Labels
# 31133  Clothing & Accessories  \
# 31134  Clothing & Accessories
# 31135  Clothing & Accessories
# 31136  Clothing & Accessories
# 31137  Clothing & Accessories
# ...                       ...
# 48470             Electronics
# 48471             Electronics
# 48472             Electronics
# 48473             Electronics
# 48474             Electronics
#
#                                                     Text
# 31133  Woopower 36M Pink for 024M Baby Trouser Top Se...
# 31134  Amour Butterfly Design Sunglasses For Girls 6+...
# 31135  Vaenait Baby 024M Baby Girls Rashguard Swimwea...
# 31136  Amour Butterfly Design Sunglasses For Girls 6+...
# 31137  Kuchipoo Girl's Cotton Regular Fit T-Shirt - P...
# ...                                                  ...
# 48470  LG GH24NSD1 Internal SATA DVD Writer The M-DIS...
# 48471  LG GP65NB60 External DVD Writer (Black) LG GP6...
# 48472  PIONEER DVD PLAYER DV-3052V Pioneer DV-3052 Mu...
# 48473  LG DP546 DVD Player (Black) DivX-This is a for...
# 48474  PODOFO 10.9cm Foldable TFT Color LCD Car Monit...
#
# [34684 rows x 2 columns]

# %%
df_merged.drop(['Household', 'Books', 'Electronics', 'Clothing & Accessories'], axis = 1)
# Out:
#                        Labels
# 31133  Clothing & Accessories  \
# 31134  Clothing & Accessories
# 31135  Clothing & Accessories
# 31136  Clothing & Accessories
# 31137  Clothing & Accessories
# ...                       ...
# 48470             Electronics
# 48471             Electronics
# 48472             Electronics
# 48473             Electronics
# 48474             Electronics
#
#                                                     Text          Type
# 31133  Woopower 36M Pink for 024M Baby Trouser Top Se...  [0, 0, 0, 1]
# 31134  Amour Butterfly Design Sunglasses For Girls 6+...  [0, 0, 0, 1]
# 31135  Vaenait Baby 024M Baby Girls Rashguard Swimwea...  [0, 0, 0, 1]
# 31136  Amour Butterfly Design Sunglasses For Girls 6+...  [0, 0, 0, 1]
# 31137  Kuchipoo Girl's Cotton Regular Fit T-Shirt - P...  [0, 0, 0, 1]
# ...                                                  ...           ...
# 48470  LG GH24NSD1 Internal SATA DVD Writer The M-DIS...  [0, 1, 0, 0]
# 48471  LG GP65NB60 External DVD Writer (Black) LG GP6...  [0, 1, 0, 0]
# 48472  PIONEER DVD PLAYER DV-3052V Pioneer DV-3052 Mu...  [0, 1, 0, 0]
# 48473  LG DP546 DVD Player (Black) DivX-This is a for...  [0, 1, 0, 0]
# 48474  PODOFO 10.9cm Foldable TFT Color LCD Car Monit...  [0, 1, 0, 0]
#
# [34684 rows x 3 columns]

# %%
Household = [1, 0, 0, 0]
Electronics = [0, 1, 0, 0]
Books = [0, 0, 1, 0]
Clo_Acce = [0, 0, 0, 1]

df_merged['Type'] = df_merged['Labels'].apply(
    lambda x: Household if x == 'Household'
    else Electronics if x == 'Electronics'
    else Books if x == 'Books'
    else Clo_Acce
)

df_merged.sample(10)
# Out:
#                        Labels
# 41415             Electronics  \
# 38597  Clothing & Accessories
# 47279             Electronics
# 33811  Clothing & Accessories
# 32744  Clothing & Accessories
# 22728                   Books
# 34915  Clothing & Accessories
# 4742                Household
# 6920                Household
# 26153                   Books
#
#                                                     Text          Type
# 41415  Samsung EVO Plus Grade 3 Class 10 128GB MicroS...  [0, 1, 0, 0]
# 38597  Amour Butterfly Design Sunglasses For Girls 6+...  [0, 0, 0, 1]
# 47279  Hikvision DS-2CE1AD0T-IRP 2MP 1080P Full HD Ni...  [0, 1, 0, 0]
# 33811  Elk Kids Baby Girls Plain Panties Brief Innerw...  [0, 0, 0, 1]
# 32744  EIO® New Born Baby Multi-Color Long Sleeve Cot...  [0, 0, 0, 1]
# 22728  Errorless Physics (Universal Self Scorer) for ...  [0, 0, 1, 0]
# 34915  Amazon Brand - Symbol Men's Regular Fit Cotton...  [0, 0, 0, 1]
# 4742   Painting Mantra Art Street Round Wall Mirror (...  [1, 0, 0, 0]
# 6920   Yun Hai Hokipo Striped Design Bamboo Dinning T...  [1, 0, 0, 0]
# 26153  Comprehensive Guide to SBI Bank PO Preliminary...  [0, 0, 1, 0]

# %%
df_merged['Type'].head(1).dtype
# Out:
# dtype('O')

# %%
df_merged['Type'][1]
# Out:
# [1, 0, 0, 0]

# %%
df_merged['Household'] = df_merged['Labels'].apply(
    lambda x: 1 if x == 'Household' else 0
)
df_merged['Electronics'] = df_merged['Labels'].apply(
    lambda x: 1 if x == 'Electronics' else 0
)
df_merged['Books'] = df_merged['Labels'].apply(
    lambda x: 1 if x == 'Books' else 0
)

df_merged['Clothing & Accessories'] = df_merged['Labels'].apply(
    lambda x: 1 if x == 'Clothing & Accessories' else 0
)

df_merged.sample(50)
# Out:
#                        Labels
# 19745                   Books  \
# 33535  Clothing & Accessories
# 3043                Household
# 20059                   Books
# 32229  Clothing & Accessories
# 3112                Household
# 32618  Clothing & Accessories
# 26683                   Books
# 36245  Clothing & Accessories
# 8467                Household
# 20746                   Books
# 20300                   Books
# 46920             Electronics
# 46937             Electronics
# 31514  Clothing & Accessories
# 33852  Clothing & Accessories
# 6249                Household
# 37742  Clothing & Accessories
# 31482  Clothing & Accessories
# 19924                   Books
# 234                 Household
# 44379             Electronics
# 8662                Household
# 21853                   Books
# 43115             Electronics
# 34811  Clothing & Accessories
# 27197                   Books
# 42703             Electronics
# 34377  Clothing & Accessories
# 19919                   Books
# 33025  Clothing & Accessories
# 22195                   Books
# 6323                Household
# 40505             Electronics
# 34656  Clothing & Accessories
# 6999                Household
# 45818             Electronics
# 44100             Electronics
# 27464                   Books
# 6259                Household
# 8044                Household
# 36407  Clothing & Accessories
# 38925  Clothing & Accessories
# 1704                Household
# 31286  Clothing & Accessories
# 27754                   Books
# 33125  Clothing & Accessories
# 33782  Clothing & Accessories
# 35391  Clothing & Accessories
# 47110             Electronics
#
#                                                     Text          Type
# 19745                          EAT THAT FROG 3RD EDITION  [0, 0, 1, 0]  \
# 33535  BLINKIN Mesh Yoga Gym and Active Sports Fitnes...  [0, 0, 0, 1]
# 3043   Usha Crisp Air Premia BV 100mm Exhaust Fan (Wh...  [1, 0, 0, 0]
# 20059  Monopoly Electronic Banking Board Game Style N...  [0, 0, 1, 0]
# 32229  US Polo Association Boys' Trousers Tend to you...  [0, 0, 0, 1]
# 3112   Usha Duos Mist Air 400mm Table Fan (Purple) Ae...  [1, 0, 0, 0]
# 32618  FabSeasons Acrylic Woolen Winter Gloves for Ba...  [0, 0, 0, 1]
# 26683  The Challenger Sale: Taking Control of the Cus...  [0, 0, 1, 0]
# 36245  Karatcart Platinum Plated Trendy Elegant Austr...  [0, 0, 0, 1]
# 8467   Pigma Peerithi Rechargeable Emergency Automati...  [1, 0, 0, 0]
# 20746  Mechanical Engineering: Conventional and Objec...  [0, 0, 1, 0]
# 20300  The Atlas of Beauty About the Author Mihaela N...  [0, 0, 1, 0]
# 46920  Turning Point Review Praise for Danielle Steel...  [0, 1, 0, 0]
# 46937  Deception Point Review Amazon Review In the wo...  [0, 1, 0, 0]
# 31514  TONYBOY Denim Full Sleeves Boys Shirts Update ...  [0, 0, 0, 1]
# 33852  Elk Girl's Cotton Printed Briefs (6-12 Months)...  [0, 0, 0, 1]
# 6249   Gala Spin Mop Rod (Compatible with only Gala m...  [1, 0, 0, 0]
# 37742  Maternity Belly Band/Extra Support for Your Ba...  [0, 0, 0, 1]
# 31482  Bold N Elegant Blue White Cute Cartoon Dungare...  [0, 0, 0, 1]
# 19924  A New Earth: Awakening Your Life's Purpose (Op...  [0, 0, 1, 0]
# 234    Gatsby Leather Styling Wax, Hard And Free, 75g...  [1, 0, 0, 0]
# 44379  Salcon Electronics 2.1 Audio Amplifier Board K...  [0, 1, 0, 0]
# 8662   Philips AstraPrime 15-Watt Recessed LED Panel ...  [1, 0, 0, 0]
# 21853  Indian Economy: For UPSC Civil Services & Othe...  [0, 0, 1, 0]
# 43115  SBE USB Wireless Remote Control Professional L...  [0, 1, 0, 0]
# 34811  Adofo Running Belt Waist Pouch for Men + Women...  [0, 0, 0, 1]
# 27197          Environmental Engineering: A Design Appr   [0, 0, 1, 0]
# 42703  Lenovo Legion Y530 Intel Core I5 8th Gen 15.6 ...  [0, 1, 0, 0]
# 34377  SAJANI Men's Cotton Lungi, 2.5 m (Multicolour,...  [0, 0, 0, 1]
# 19919  A Short History of Nearly Everything (Re-issue...  [0, 0, 1, 0]
# 33025  J B Fashion Women's Animal Print Regular fit (...  [0, 0, 0, 1]
# 22195  STUDY MATERIALS FOR IGNOU OPENMAT [ PACK OF 4 ...  [0, 0, 1, 0]
# 6323   Homefab India Jute Modern 2 Piece Eyelet Polye...  [1, 0, 0, 0]
# 40505  Trishago Capping Head Assembly for Epson L210 ...  [0, 1, 0, 0]
# 34656                   Rupa Thermocot Men's Thermal Top  [0, 0, 0, 1]
# 6999   Shop4All Automatic Toothpaste Dispenser and 5 ...  [1, 0, 0, 0]
# 45818  Aerograph Airbrush Mini Air-Compressor Profess...  [0, 1, 0, 0]
# 44100  DeckUp Minang TV Stand and Home Entertainment ...  [0, 1, 0, 0]
# 27464  The Bloomsbury Research Handbook of Chinese Ph...  [0, 0, 1, 0]
# 6259   SPORTO Fitness 3 FIT Sated Rod (21 MM) ✔️ FEET...  [1, 0, 0, 0]
# 8044   KRIWIN Sahaya Set Of 2 Polyester Big Size Mesh...  [1, 0, 0, 0]
# 36407  Indira Designer Women's Cotton Saree With Blou...  [0, 0, 0, 1]
# 38925  Under Armour Women's Cap Structured buckram ca...  [0, 0, 0, 1]
# 1704   Cello Novelty Large Cupboard - Ice Brown Color...  [1, 0, 0, 0]
# 31286  GoMerryKids Baby's Light Weight Regular Fit Co...  [0, 0, 0, 1]
# 27754  The Visual Story: Creating the Visual Structur...  [0, 0, 1, 0]
# 33125  CUPID Regular FIT Women Cotton Trackpants (M t...  [0, 0, 0, 1]
# 33782  chirsh® Baby Cotton Pajamas/Lowers/Track Pants...  [0, 0, 0, 1]
# 35391  Park Avenue Men's Waistcoat Unleash the true f...  [0, 0, 0, 1]
# 47110  Deception Point Amazon.com Review Penzler Pick...  [0, 1, 0, 0]
#
#        Household  Electronics  Books  Clothing & Accessories
# 19745          0            0      1                       0
# 33535          0            0      0                       1
# 3043           1            0      0                       0
# 20059          0            0      1                       0
# 32229          0            0      0                       1
# 3112           1            0      0                       0
# 32618          0            0      0                       1
# 26683          0            0      1                       0
# 36245          0            0      0                       1
# 8467           1            0      0                       0
# 20746          0            0      1                       0
# 20300          0            0      1                       0
# 46920          0            1      0                       0
# 46937          0            1      0                       0
# 31514          0            0      0                       1
# 33852          0            0      0                       1
# 6249           1            0      0                       0
# 37742          0            0      0                       1
# 31482          0            0      0                       1
# 19924          0            0      1                       0
# 234            1            0      0                       0
# 44379          0            1      0                       0
# 8662           1            0      0                       0
# 21853          0            0      1                       0
# 43115          0            1      0                       0
# 34811          0            0      0                       1
# 27197          0            0      1                       0
# 42703          0            1      0                       0
# 34377          0            0      0                       1
# 19919          0            0      1                       0
# 33025          0            0      0                       1
# 22195          0            0      1                       0
# 6323           1            0      0                       0
# 40505          0            1      0                       0
# 34656          0            0      0                       1
# 6999           1            0      0                       0
# 45818          0            1      0                       0
# 44100          0            1      0                       0
# 27464          0            0      1                       0
# 6259           1            0      0                       0
# 8044           1            0      0                       0
# 36407          0            0      0                       1
# 38925          0            0      0                       1
# 1704           1            0      0                       0
# 31286          0            0      0                       1
# 27754          0            0      1                       0
# 33125          0            0      0                       1
# 33782          0            0      0                       1
# 35391          0            0      0                       1
# 47110          0            1      0                       0

# %% [markdown]
# ### ***Splitting dataframe***

# %%
cols = df_merged.select_dtypes(include=['object'])
for col in cols.columns.values:
    df_merged[col] = df_merged[col].fillna('')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_merged['Text'], df_merged['Type'], train_size=0.09, stratify=df_merged['Type'])
y_train.head()
# Out:
# 36681    [0, 0, 0, 1]
# 35662    [0, 0, 0, 1]
# 26569    [0, 0, 1, 0]
# 7349     [1, 0, 0, 0]
# 40428    [0, 1, 0, 0]
# Name: Type, dtype: object

# %% [markdown]
# ### ***Importing BERT and getting embeding vectors for data***

# %%
bert_preprocess = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
bert_encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4")

# %% [markdown]
# **Example getting embeding of sentence**

# %%
def get_sentence_embeding(sentences):
    preprocessed_text = bert_preprocess(sentences)
    return bert_encoder(preprocessed_text)['pooled_output']

get_sentence_embeding([
    "500$ discount. hurry up", 
    "Bhavin, are you up for a volleybal game tomorrow?"]
)

# %% [markdown]
# **Building model**

# %%
#BERT Layer
text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name = "text")
preprocessed_inputs = bert_preprocess(text_input)
encoded_outputs = bert_encoder(preprocessed_inputs)

#Neural network
layer = tf.keras.layers.Dropout(0.1, name='dropout') (encoded_outputs['pooled_output'])
layer= tf.keras.layers.Dense(4, activation='sigmoid', name="output")(layer)

#Construct the final model
model = tf.keras.Model(inputs=[text_input], outputs=[layer])

# %%
encoded_outputs['pooled_output'][4]
# Out:
# <KerasTensor: shape=(768,) dtype=float32 (created by layer 'tf.__operators__.getitem_3')>

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text (InputLayer)              [(None,)]            0           []
#
#  keras_layer (KerasLayer)       {'input_word_ids':   0           ['text[0][0]']
#                                 (None, 128),
#                                  'input_mask': (Non
#                                 e, 128),
#                                  'input_type_ids':
#                                 (None, 128)}
#
#  keras_layer_1 (KerasLayer)     {'default': (None,   109482241   ['keras_layer[3][0]',
#                                 768),                             'keras_layer[3][1]',
#                                  'encoder_outputs':               'keras_layer[3][2]']
#                                  [(None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768)],
#                                  'pooled_output': (
#                                 None, 768),
#                                  'sequence_output':
#                                  (None, 128, 768)}
#
#  dropout (Dropout)              (None, 768)          0           ['keras_layer_1[3][13]']
#
#  output (Dense)                 (None, 4)            3076        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 109,485,317
# Trainable params: 3,076
# Non-trainable params: 109,482,241
# __________________________________________________________________________________________________

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(), optimizer='adam',
              metrics=[tf.keras.metrics.BinaryAccuracy(name = 'Accuracy'),
                       tf.keras.metrics.Precision(name = 'Precision'), 
                       tf.keras.metrics.Recall(name = 'Recall')])

# %%
y_train = y_train.astype(str)

# %%
y_train.head(10)
# Out:
# 36681    [0, 0, 0, 1]
# 35662    [0, 0, 0, 1]
# 26569    [0, 0, 1, 0]
# 7349     [1, 0, 0, 0]
# 40428    [0, 1, 0, 0]
# 44173    [0, 1, 0, 0]
# 46171    [0, 1, 0, 0]
# 4267     [1, 0, 0, 0]
# 19940    [0, 0, 1, 0]
# 21308    [0, 0, 1, 0]
# Name: Type, dtype: object

# %%
from keras.models import Sequential
from keras.layers import Dense

MODEL = Sequential()
MODEL.add(Dense(20, input_dim = 768, kernel_initializer='he_uniform', activation='relu'))
MODEL.add(Dense(4, activation = 'sigmoid'))
MODEL.compile(loss='binary_crossentropy', optimizer='adam')

# %%
MODEL.fit(X_train, y_train, verbose=0, epochs=3)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 768) for input KerasTensor(type_spec=TensorSpec(shape=(None, 768), dtype=tf.float32, name='dense_24_input'), name='dense_24_input', description="created by layer 'dense_24_input'"), but it was called on an input with incompatible shape (None, 1).
# WARNING:tensorflow:Model was constructed with shape (None, 768) for input KerasTensor(type_spec=TensorSpec(shape=(None, 768), dtype=tf.float32, name='dense_24_input'), name='dense_24_input', description="created by layer 'dense_24_input'"), but it was called on an input with incompatible shape (None, 1).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 MODEL.fit(X_train, y_train, verbose=0, epochs=3)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_fileyquslx57.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\input_spec.py", line 277, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Exception encountered when calling layer "sequential_12" "                 f"(type Sequential).
#
#     Input 0 of layer "dense_24" is incompatible with the layer: expected axis -1 of input shape to have value 768, but received input with shape (None, 1)
#
#     Call arguments received by layer "sequential_12" "                 f"(type Sequential):
#       • inputs=tf.Tensor(shape=(None, 1), dtype=string)
#       • training=True
#       • mask=None

# %%
import numpy as np
y_train = np.asarray(y_train).astype(np.int64)
model.fit(X_train, y_train, epochs = 10)
